# %% [markdown]
# # 【問題集】第6章：関数（def / 引数 / 戻り値 / スコープ / *args・**kwargs / lambda）
#
# Python 3 エンジニア認定基礎試験 対策 / 問46〜問60（解答・解説なし・生徒配布用）
#
# 各問の選択肢から正解を選び、コードセルの `___`（アンダーバー3つ）を埋めて実行してみましょう。

# %% [markdown]
# ### 問46. 関数の定義（def）と呼び出し
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def greet(name):
#     return "Hello, " + name
#
# print(greet("Python"))
# ```
#
# **【選択肢】**
# - A) Hello, Python
# - B) Hello, name
# - C) greet Python
# - D) エラーになる

# %%
# 関数を定義するキーワードを埋めてください。
___ greet(name):
    return "Hello, " + name

print(greet("Python"))   # Hello, Python

# %% [markdown]
# ### 問47. 戻り値（return）の利用
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def add(a, b):
#     return a + b
#
# result = add(3, 4)
# print(result * 2)
# ```
#
# **【選択肢】**
# - A) 7
# - B) 14
# - C) 34
# - D) None

# %%
# 2つの引数の和を返し、その戻り値を使って計算します。戻り値を返すキーワードを埋めてください。
def add(a, b):
    ___ a + b

result = add(3, 4)
print(result * 2)   # 14

# %% [markdown]
# ### 問48. デフォルト引数
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def power(base, exp=2):
#     return base ** exp
#
# print(power(3))
# print(power(2, 3))
# ```
#
# **【選択肢】**
# - A) 9 / 8
# - B) 6 / 6
# - C) 9 / 6
# - D) エラーになる

# %%
# exp を省略したら 2 乗になるよう、デフォルト値を設定してください。
def power(base, exp___2):
    return base ** exp

print(power(3))      # 9
print(power(2, 3))   # 8

# %% [markdown]
# ### 問49. キーワード引数
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def introduce(name, age):
#     return name + " is " + str(age)
#
# print(introduce(age=20, name="Taro"))
# ```
#
# **【選択肢】**
# - A) Taro is 20
# - B) 20 is Taro
# - C) name is age
# - D) エラーになる

# %%
# 引数名を指定して渡します（キーワード引数）。呼び出し側の空欄を埋めてください。
def introduce(name, age):
    return name + " is " + str(age)

print(introduce(___=20, ___="Taro"))   # Taro is 20

# %% [markdown]
# ### 問50. 位置引数とキーワード引数の順序
#
# 次のうち、関数 `f(a, b, c)` の呼び出しとして**文法エラーになる**ものを選んでください。
#
# ```python
# def f(a, b, c):
#     return (a, b, c)
# ```
#
# **【選択肢】**
# - A) f(1, 2, 3)
# - B) f(1, c=3, b=2)
# - C) f(a=1, b=2, c=3)
# - D) f(a=1, 2, 3)

# %%
# 位置引数はキーワード引数より前に書く必要があります。正しい呼び出しになるよう埋めてください。
def f(a, b, c):
    return (a, b, c)

print(f(1, ___=3, ___=2))   # (1, 2, 3)

# %% [markdown]
# ### 問51. 可変長位置引数（*args）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def total(*nums):
#     return sum(nums)
#
# print(total(1, 2, 3, 4))
# ```
#
# **【選択肢】**
# - A) 10
# - B) 4
# - C) (1, 2, 3, 4)
# - D) エラーになる

# %%
# 任意個の引数を受け取れるようにします。可変長位置引数の記号を埋めてください。
def total(___nums):
    return sum(nums)

print(total(1, 2, 3, 4))   # 10

# %% [markdown]
# ### 問52. 可変長キーワード引数（**kwargs）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def show(**info):
#     return info
#
# print(show(name="Taro", age=20))
# ```
#
# **【選択肢】**
# - A) {'name': 'Taro', 'age': 20}
# - B) ('Taro', 20)
# - C) ['name', 'age']
# - D) name age

# %%
# 任意のキーワード引数を辞書として受け取ります。記号を埋めてください。
def show(___info):
    return info

print(show(name="Taro", age=20))   # {'name': 'Taro', 'age': 20}

# %% [markdown]
# ### 問53. 引数リストのアンパック
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def add(a, b, c):
#     return a + b + c
#
# nums = [1, 2, 3]
# print(add(*nums))
# ```
#
# **【選択肢】**
# - A) 6
# - B) [1, 2, 3]
# - C) 123
# - D) エラーになる

# %%
# リストを個々の引数に展開して渡します。展開の記号を埋めてください。
def add(a, b, c):
    return a + b + c

nums = [1, 2, 3]
print(add(___nums))   # 6

# %% [markdown]
# ### 問54. ローカル変数のスコープ
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# x = 10
# def change():
#     x = 5
#     return x
#
# print(change())
# print(x)
# ```
#
# **【選択肢】**
# - A) 5 / 10
# - B) 5 / 5
# - C) 10 / 10
# - D) 10 / 5

# %%
# 関数内の x はローカル変数です。関数の戻り値を返すキーワードを埋めてください。
x = 10
def change():
    x = 5
    ___ x

print(change())   # 5
print(x)          # 10

# %% [markdown]
# ### 問55. global 文
#
# 次のコードでグローバル変数 count を関数内から変更し、出力を 1 にするために空欄へ入れるものを選んでください。
#
# ```python
# count = 0
# def increment():
#     ___ count
#     count += 1
#
# increment()
# print(count)
# ```
#
# **【選択肢】**
# - A) global
# - B) nonlocal
# - C) local
# - D) return

# %%
# 関数内からグローバル変数を変更する宣言を埋めてください。
count = 0
def increment():
    ___ count
    count += 1

increment()
print(count)   # 1

# %% [markdown]
# ### 問56. return を書かない関数の戻り値
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def show(msg):
#     print(msg)
#
# result = show("hi")
# print(result)
# ```
#
# **【選択肢】**
# - A) hi / None
# - B) hi / hi
# - C) None / None
# - D) hi のみ

# %%
# 関数内で msg を表示する組み込み関数を埋めてください。
# この関数は return がないため、戻り値は None になります。
def show(msg):
    ___(msg)

result = show("hi")
print(result)   # 1行目: hi / 2行目: None

# %% [markdown]
# ### 問57. lambda（無名関数）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# square = lambda x: x ** 2
# print(square(5))
# ```
#
# **【選択肢】**
# - A) 25
# - B) 10
# - C) x ** 2
# - D) エラーになる

# %%
# 引数 x を2乗して返す無名関数を作ります。無名関数のキーワードを埋めてください。
square = ___ x: x ** 2
print(square(5))   # 25

# %% [markdown]
# ### 問58. sorted() の key に lambda を使う
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# pairs = [(1, "b"), (2, "a"), (3, "c")]
# result = sorted(pairs, key=lambda p: p[1])
# print(result)
# ```
#
# **【選択肢】**
# - A) [(2, 'a'), (1, 'b'), (3, 'c')]
# - B) [(1, 'b'), (2, 'a'), (3, 'c')]
# - C) [(3, 'c'), (2, 'a'), (1, 'b')]
# - D) エラーになる

# %%
# 各タプルの2番目の要素（文字）で並べ替えます。key に渡す lambda の本体を埋めてください。
pairs = [(1, "b"), (2, "a"), (3, "c")]
result = sorted(pairs, key=lambda p: ___)
print(result)   # [(2, 'a'), (1, 'b'), (3, 'c')]

# %% [markdown]
# ### 問59. ドキュメンテーション文字列（docstring）
#
# 次のコードで関数の説明文（docstring）を取得して表示するために空欄へ入れるものを選んでください。
#
# ```python
# def greet():
#     """あいさつを返す関数"""
#     return "hi"
#
# print(greet.___)
# ```
#
# **【選択肢】**
# - A) __doc__
# - B) __name__
# - C) __str__
# - D) doc()

# %%
# 関数の直後の """..." がdocstringです。それを取り出す属性を埋めてください。
def greet():
    """あいさつを返す関数"""
    return "hi"

print(greet.___)   # あいさつを返す関数

# %% [markdown]
# ### 問60. 複数の値を返す（タプルのアンパック）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# def minmax(nums):
#     return min(nums), max(nums)
#
# low, high = minmax([3, 1, 4, 1, 5])
# print(low, high)
# ```
#
# **【選択肢】**
# - A) 1 5
# - B) 5 1
# - C) (1, 5)
# - D) 3 5

# %%
# 最小値と最大値をまとめて返し、2つの変数で受け取ります。戻り値の並びを埋めてください。
def minmax(nums):
    return ___(nums), ___(nums)

low, high = minmax([3, 1, 4, 1, 5])
print(low, high)   # 1 5
