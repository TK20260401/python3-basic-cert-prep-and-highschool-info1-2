# %% [markdown]
# # 【問題集】第7章：モジュール（import / from / as / 標準ライブラリ）
#
# Python 3 エンジニア認定基礎試験 対策 / 問61〜問75（解答・解説なし・生徒配布用）
#
# 各問の選択肢から正解を選び、コードセルの `___`（アンダーバー3つ）を埋めて実行してみましょう。

# %% [markdown]
# ### 問61. モジュールの import と関数呼び出し
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.sqrt(16))
# ```
#
# **【選択肢】**
# - A) 4.0
# - B) 4
# - C) 256
# - D) エラーになる

# %%
# math モジュールを取り込みます。取り込むキーワードを埋めてください。
___ math
print(math.sqrt(16))   # 4.0

# %% [markdown]
# ### 問62. from ... import で名前を直接取り込む
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# from math import pi
# print(round(pi, 2))
# ```
#
# **【選択肢】**
# - A) 3.14
# - B) 3.141592653589793
# - C) math.pi
# - D) エラーになる

# %%
# math モジュールから pi だけを直接取り込みます。空欄を埋めてください。
___ math ___ pi
print(round(pi, 2))   # 3.14

# %% [markdown]
# ### 問63. import ... as で別名を付ける
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math as m
# print(m.floor(3.7))
# ```
#
# **【選択肢】**
# - A) 3
# - B) 4
# - C) 3.7
# - D) エラーになる

# %%
# math モジュールに m という別名を付けます。別名を付けるキーワードを埋めてください。
import math ___ m
print(m.floor(3.7))   # 3

# %% [markdown]
# ### 問64. 複数の名前をまとめて import
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# from math import ceil, floor
# print(ceil(3.2), floor(3.8))
# ```
#
# **【選択肢】**
# - A) 4 3
# - B) 3 4
# - C) 3 3
# - D) 4 4

# %%
# ceil と floor を1行でまとめて取り込みます。区切り文字を埋めてください。
from math import ceil ___ floor
print(ceil(3.2), floor(3.8))   # 4 3

# %% [markdown]
# ### 問65. random モジュールで乱数を扱う
#
# 次のコードについて、変数 n に入りうる値として正しい範囲を選んでください。
#
# ```python
# import random
# n = random.randint(1, 6)
# print(n)
# ```
#
# **【選択肢】**
# - A) 1 以上 6 以下の整数
# - B) 1 以上 6 未満の整数
# - C) 0 以上 6 以下の整数
# - D) 0.0 以上 6.0 未満の小数

# %%
# 1 から 6 までのサイコロの目を作ります。使うモジュールを埋めてください。
import ___
n = random.randint(1, 6)
print(n)   # 1〜6 のいずれか

# %% [markdown]
# ### 問66. random.choice でリストから1つ選ぶ
#
# 次のコードの説明として正しいものを選んでください。
#
# ```python
# import random
# fruits = ["apple", "banana", "cherry"]
# print(random.choice(fruits))
# ```
#
# **【選択肢】**
# - A) リストの中からランダムに1つの要素を返す
# - B) リストを毎回シャッフルして全体を返す
# - C) 先頭の要素を返す
# - D) リストの要素数を返す

# %%
# リストからランダムに1つ選ぶ関数を埋めてください。
import random
fruits = ["apple", "banana", "cherry"]
print(random.___(fruits))   # いずれか1つ

# %% [markdown]
# ### 問67. dir() でモジュールの中身を調べる
#
# 次のコードの説明として正しいものを選んでください。
#
# ```python
# import math
# print(type(dir(math)))
# ```
#
# **【選択肢】**
# - A) dir(math) はモジュール内の名前のリストを返すので <class 'list'>
# - B) dir(math) は文字列を返すので <class 'str'>
# - C) dir(math) は辞書を返すので <class 'dict'>
# - D) エラーになる

# %%
# モジュール内で定義されている名前の一覧を得る組み込み関数を埋めてください。
import math
print(type(___(math)))   # <class 'list'>

# %% [markdown]
# ### 問68. if __name__ == "__main__"
#
# 次の説明で、`if __name__ == "__main__":` の役割として正しいものを選んでください。
#
# ```python
# def main():
#     print("実行されました")
#
# if __name__ == "__main__":
#     main()
# ```
#
# **【選択肢】**
# - A) ファイルを直接実行したときだけ main() を呼び、import されたときは呼ばない
# - B) import されたときだけ main() を呼ぶ
# - C) 常に main() を呼ぶ
# - D) main という名前を予約する

# %%
# 直接実行時のみ動かす定番の条件です。比較する特殊変数を埋めてください。
def main():
    print("実行されました")

if ___ == "__main__":
    main()

# %% [markdown]
# ### 問69. sys モジュール
#
# 次のコードを実行したときの出力として正しいものを選んでください（Python 3 系の場合）。
#
# ```python
# import sys
# print(sys.version_info.major)
# ```
#
# **【選択肢】**
# - A) 3
# - B) "3.x.x"
# - C) python
# - D) エラーになる

# %%
# インタプリタや実行環境の情報を扱うモジュールを埋めてください。
import ___
print(sys.version_info.major)   # 3

# %% [markdown]
# ### 問70. os モジュール
#
# 次のコードの説明として正しいものを選んでください。
#
# ```python
# import os
# print(type(os.getcwd()))
# ```
#
# **【選択肢】**
# - A) getcwd() は現在の作業ディレクトリ（カレントディレクトリ）を文字列で返す
# - B) getcwd() はファイル一覧をリストで返す
# - C) getcwd() は環境変数を辞書で返す
# - D) エラーになる

# %%
# OSやファイルシステムを操作するモジュールを埋めてください。
import ___
print(type(os.getcwd()))   # <class 'str'>

# %% [markdown]
# ### 問71. datetime モジュール
#
# 次のコードを実行したときの `d` の型として正しいものを選んでください。
#
# ```python
# import datetime
# d = datetime.date(2025, 1, 15)
# print(d.year)
# ```
#
# **【選択肢】**
# - A) 2025 が表示される
# - B) 1 が表示される
# - C) 15 が表示される
# - D) エラーになる

# %%
# 日付を表す date オブジェクトを作り、年を取り出します。属性名を埋めてください。
import datetime
d = datetime.date(2025, 1, 15)
print(d.___)   # 2025

# %% [markdown]
# ### 問72. math モジュールの定数と関数
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.pow(2, 3))
# ```
#
# **【選択肢】**
# - A) 8.0
# - B) 8
# - C) 6
# - D) 9

# %%
# 2 の 3 乗を math の関数で求めます。関数名を埋めてください。
import math
print(math.___(2, 3))   # 8.0

# %% [markdown]
# ### 問73. from module import *（ワイルドカード）
#
# 次の説明のうち、`from math import *` の性質として正しいものを選んでください。
#
# ```python
# from math import *
# print(sqrt(9))
# ```
#
# **【選択肢】**
# - A) モジュール内の多くの名前を一括で取り込むが、名前の衝突が起きやすく非推奨
# - B) 構文エラーになる
# - C) math モジュールを別名 * として取り込む
# - D) 何も取り込まない

# %%
# math の名前を一括で取り込みます（* を使う書き方）。ワイルドカード記号を埋めてください。
from math import ___
print(sqrt(9))   # 3.0

# %% [markdown]
# ### 問74. サブモジュール（os.path）
#
# 次のコードの説明として正しいものを選んでください。
#
# ```python
# import os
# print(os.path.join("dir", "file.txt"))
# ```
#
# **【選択肢】**
# - A) os のサブモジュール os.path の join でパスを連結する
# - B) 文字列を単純に + で連結するだけ
# - C) ファイルを実際に作成する
# - D) エラーになる

# %%
# os のサブモジュールを使ってパスを組み立てます。サブモジュール名を埋めてください。
import os
print(os.___.join("dir", "file.txt"))   # dir/file.txt など

# %% [markdown]
# ### 問75. from import した関数を別名で使う
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# from math import sqrt as root
# print(root(25))
# ```
#
# **【選択肢】**
# - A) 5.0
# - B) 5
# - C) 625
# - D) エラーになる

# %%
# math の sqrt を root という別名で取り込みます。空欄を埋めてください。
from math import sqrt ___ root
print(root(25))   # 5.0
