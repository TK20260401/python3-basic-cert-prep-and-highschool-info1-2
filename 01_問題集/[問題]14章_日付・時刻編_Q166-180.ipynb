# %% [markdown]
# # 第14章 日付・時刻編 問題集（Q166〜Q180）
#
# Python 3 エンジニア認定基礎試験 オリジナル問題集。各問、空欄 `___` に当てはまる語句(A〜D)を選び、コードセルを実行して確認しましょう。

# %% [markdown]
# ### 問166
# 日付（年・月・日）を表すオブジェクトを作るには、どのクラスを使うか。
#
# - A. `datetime.date`
# - B. `datetime.time`
# - C. `datetime.delta`
# - D. `datetime.calendar`

# %%
import datetime
d = datetime.___(2024, 4, 1)
print(d)

# %% [markdown]
# ### 問167
# datetime.datetime オブジェクトから月を取り出すには、どの属性を使うか。
#
# - A. `.month`
# - B. `.mon`
# - C. `.months`
# - D. `.getMonth()`

# %%
import datetime
dt = datetime.datetime(2024, 4, 1, 9, 30, 0)
print(dt.___)

# %% [markdown]
# ### 問168
# 実行時点の今日の日付を取得するメソッドはどれか。
#
# - A. `datetime.date.today()`
# - B. `datetime.date.now()`
# - C. `datetime.today.date()`
# - D. `datetime.now.date()`

# %%
import datetime
today = datetime.date.___()
print(type(today))

# %% [markdown]
# ### 問169
# ある日付の7日後を求めるには、どのクラスを使って加算するか。
#
# - A. `datetime.timedelta`
# - B. `datetime.delta`
# - C. `datetime.interval`
# - D. `datetime.duration`

# %%
import datetime
d = datetime.date(2024, 4, 1)
future = d + datetime.___(days=7)
print(future)

# %% [markdown]
# ### 問170
# 2つの日付の差（経過日数）を求める演算子はどれか。
#
# - A. `-`
# - B. `+`
# - C. `//`
# - D. `%`

# %%
import datetime
d1 = datetime.date(2024, 4, 10)
d2 = datetime.date(2024, 4, 1)
diff = d1 ___ d2
print(diff.days)

# %% [markdown]
# ### 問171
# timedeltaオブジェクトから日数（整数）を取り出す属性はどれか。
#
# - A. `.days`
# - B. `.day`
# - C. `.total_days`
# - D. `.d`

# %%
import datetime
delta = datetime.timedelta(days=5, hours=3)
print(delta.___)

# %% [markdown]
# ### 問172
# datetimeオブジェクトを指定書式の文字列に変換するメソッドはどれか。
#
# - A. `.strftime()`
# - B. `.strptime()`
# - C. `.format()`
# - D. `.isoformat()`

# %%
import datetime
dt = datetime.datetime(2024, 4, 1, 9, 5, 0)
print(dt.___("%Y/%m/%d %H:%M"))

# %% [markdown]
# ### 問173
# 文字列をdatetimeオブジェクトに変換する関数/メソッドはどれか。
#
# - A. `datetime.datetime.strptime`
# - B. `datetime.datetime.strftime`
# - C. `datetime.datetime.parse`
# - D. `datetime.datetime.fromtext`

# %%
import datetime
s = "2024-04-01"
dt = datetime.datetime.___(s, "%Y-%m-%d")
print(dt)

# %% [markdown]
# ### 問174
# 時（24時間表記）をゼロ埋め2桁で表すフォーマットコードはどれか。
#
# - A. `H`
# - B. `h`
# - C. `HH`
# - D. `24`

# %%
import datetime
dt = datetime.datetime(2024, 4, 1, 9, 5, 3)
print(dt.strftime("%___:%M:%S"))

# %% [markdown]
# ### 問175
# date型同士は比較演算子で大小を比較できる。d1がd2より過去かどうかを判定する式はどれか。
#
# - A. `d1 < d2`
# - B. `d1 << d2`
# - C. `d1 diff d2`
# - D. `compare(d1, d2)`

# %%
import datetime
d1 = datetime.date(2024, 1, 1)
d2 = datetime.date(2024, 12, 31)
print(d1 ___ d2)

# %% [markdown]
# ### 問176
# 現在時刻をUNIXエポック秒（float）で取得する関数はどれか。
#
# - A. `time.time()`
# - B. `time.now()`
# - C. `time.clock()`
# - D. `time.epoch()`

# %%
import time
t = time.___()
print(type(t))

# %% [markdown]
# ### 問177
# 指定した秒数だけ処理を一時停止する関数はどれか。
#
# - A. `time.sleep()`
# - B. `time.wait()`
# - C. `time.pause()`
# - D. `time.delay()`

# %%
import time
start = time.time()
time.___(1)
elapsed = time.time() - start
print(elapsed >= 1)

# %% [markdown]
# ### 問178
# 2週間後の日付を timedelta で求めるとき、正しいキーワード引数はどれか。
#
# - A. `weeks=2`
# - B. `week=2`
# - C. `days=2`
# - D. `w=2`

# %%
import datetime
d = datetime.date(2024, 4, 1)
future = d + datetime.timedelta(___)
print(future)

# %% [markdown]
# ### 問179
# date/datetimeの weekday() メソッドで月曜日を表す戻り値はどれか。
#
# - A. `0`
# - B. `1`
# - C. `7`
# - D. `"Mon"`

# %%
import datetime
d = datetime.date(2024, 4, 1)  # 2024年4月1日は月曜日
print(d.weekday() == ___)

# %% [markdown]
# ### 問180
# datetimeオブジェクトをISO 8601形式の文字列に変換するメソッドはどれか。
#
# - A. `.isoformat()`
# - B. `.isodate()`
# - C. `.to_iso()`
# - D. `.format_iso()`

# %%
import datetime
dt = datetime.datetime(2024, 4, 1, 9, 5, 3)
print(dt.___())
