# %% [markdown]
# # 第12章 標準ライブラリ応用編 問題集（Q136〜Q150）
#
# Python 3 エンジニア認定基礎試験 オリジナル問題集。各問、空欄 `___` に当てはまる語句(A〜D)を選び、コードセルを実行して確認しましょう。

# %% [markdown]
# ### 問136
# 文字列の中から正規表現パターンに最初にマッチする部分を検索したい。空欄 `___` に入る `re` モジュールの関数名を選べ。
#
# - A. `search`
# - B. `count`
# - C. `index`
# - D. `find`

# %%
import re
text = "Python 3.12 is great"
m = re.___(r"\d+\.\d+", text)
print(m.group())

# %% [markdown]
# ### 問137
# 文字列内でパターンに一致する部分をすべてリストとして取得したい。空欄に入る関数名を選べ。
#
# - A. `findall`
# - B. `search`
# - C. `match`
# - D. `fullmatch`

# %%
import re
text = "apple:100, banana:200, cherry:300"
nums = re.___(r"\d+", text)
print(nums)

# %% [markdown]
# ### 問138
# 文字列中のパターンに一致する部分を別の文字列に置き換えたい。空欄に入る関数名を選べ。
#
# - A. `sub`
# - B. `replace`
# - C. `sub_all`
# - D. `change`

# %%
import re
text = "2026-07-21"
result = re.___(r"-", "/", text)
print(result)

# %% [markdown]
# ### 問139
# 正規表現パターンを区切り文字として文字列を分割したい。空欄に入る関数名を選べ。
#
# - A. `split`
# - B. `sub`
# - C. `divide`
# - D. `cut`

# %%
import re
text = "a1b22c333d"
parts = re.___(r"\d+", text)
print(parts)

# %% [markdown]
# ### 問140
# 同じ正規表現パターンを繰り返し使う場合、事前にコンパイルして再利用できるオブジェクトを作りたい。空欄に入る関数名を選べ。
#
# - A. `compile`
# - B. `build`
# - C. `parse`
# - D. `prepare`

# %%
import re
pattern = re.___(r"\d+")
print(pattern.findall("A12 B34"))

# %% [markdown]
# ### 問141
# リストの要素ごとの出現回数を数えたい。`collections` モジュールの何を使うか選べ。
#
# - A. `Counter`
# - B. `defaultdict`
# - C. `OrderedDict`
# - D. `deque`

# %%
from collections import ___
data = ["a", "b", "a", "c", "b", "a"]
counts = ___(data)
print(counts["a"])

# %% [markdown]
# ### 問142
# 辞書に存在しないキーへアクセスした際に自動で初期値を生成したい。`collections` モジュールの何を使うか選べ。
#
# - A. `defaultdict`
# - B. `Counter`
# - C. `namedtuple`
# - D. `deque`

# %%
from collections import ___
d = ___(list)
d["fruits"].append("apple")
print(d["fruits"])

# %% [markdown]
# ### 問143
# フィールド名でアクセスできる軽量なタプルのようなクラスを作りたい。`collections` モジュールの何を使うか選べ。
#
# - A. `namedtuple`
# - B. `Counter`
# - C. `deque`
# - D. `defaultdict`

# %%
from collections import ___
Point = ___("Point", ["x", "y"])
p = Point(3, 4)
print(p.x, p.y)

# %% [markdown]
# ### 問144
# リストの両端への追加・削除を高速に行いたい。`collections` モジュールの何を使うか選べ。
#
# - A. `deque`
# - B. `Counter`
# - C. `namedtuple`
# - D. `OrderedDict`

# %%
from collections import ___
dq = ___([1, 2, 3])
dq.appendleft(0)
dq.append(4)
print(list(dq))

# %% [markdown]
# ### 問145
# 複数のiterableを連結して1つのイテレータとして扱いたい。`itertools` モジュールの何を使うか選べ。
#
# - A. `chain`
# - B. `product`
# - C. `cycle`
# - D. `count`

# %%
from itertools import ___
result = list(___([1, 2], [3, 4], [5]))
print(result)

# %% [markdown]
# ### 問146
# 複数のiterableのデカルト積（すべての組み合わせ）を得たい。`itertools` モジュールの何を使うか選べ。
#
# - A. `product`
# - B. `chain`
# - C. `permutations`
# - D. `combinations`

# %%
from itertools import ___
result = list(___([1, 2], ["a", "b"]))
print(result)

# %% [markdown]
# ### 問147
# 要素の並び順を区別したすべての順列を得たい。`itertools` モジュールの何を使うか選べ。
#
# - A. `permutations`
# - B. `combinations`
# - C. `product`
# - D. `chain`

# %%
from itertools import ___
result = list(___([1, 2, 3], 2))
print(len(result))

# %% [markdown]
# ### 問148
# 要素の組み合わせ（順序を区別しない）を得たい。`itertools` モジュールの何を使うか選べ。
#
# - A. `combinations`
# - B. `permutations`
# - C. `product`
# - D. `chain`

# %%
from itertools import ___
result = list(___([1, 2, 3], 2))
print(len(result))

# %% [markdown]
# ### 問149
# リストの要素を順に累積的に演算し1つの値にまとめたい。`functools` モジュールの何を使うか選べ。
#
# - A. `reduce`
# - B. `partial`
# - C. `wraps`
# - D. `lru_cache`

# %%
from functools import ___
result = ___(lambda a, b: a * b, [1, 2, 3, 4])
print(result)

# %% [markdown]
# ### 問150
# 関数の呼び出し結果をキャッシュして再計算を避けたい。`functools` モジュールの何のデコレータを使うか選べ。
#
# - A. `lru_cache`
# - B. `reduce`
# - C. `partial`
# - D. `wraps`

# %%
from functools import ___

@___()
def square(n):
    print("計算中:", n)
    return n * n

print(square(4))
print(square(4))
