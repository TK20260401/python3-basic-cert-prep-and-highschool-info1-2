# %% [markdown]
# # 第10章 クラス編（Q106-120）問題集
#
# Python 3 エンジニア認定基礎試験 オリジナル問題集。各コードセルの `___`（3つのアンダースコア）に入る選択肢（A〜D）を選んでください。

# %% [markdown]
# ### 問106 クラスの定義
# クラスを定義するときに使うキーワードはどれ？
#
# - A. `def`
# - B. `class`
# - C. `struct`
# - D. `object`

# %%
___ Dog:
    pass

d = Dog()

# %% [markdown]
# ### 問107 コンストラクタ（初期化メソッド）
# インスタンス生成時に自動で呼ばれる初期化メソッドの名前はどれ？
#
# - A. `__new__`
# - B. `__init__`
# - C. `__start__`
# - D. `constructor`

# %%
class Dog:
    def ___(self, name):
        self.name = name

d = Dog('ポチ')

# %% [markdown]
# ### 問108 メソッドの第1引数
# インスタンスメソッドの第1引数として慣習的に書く、そのインスタンス自身を指す名前はどれ？
#
# - A. `this`
# - B. `self`
# - C. `me`
# - D. `cls`

# %%
class Dog:
    def __init__(___, name):
        self.name = name

# %% [markdown]
# ### 問109 インスタンス属性へのアクセス
# メソッド内でインスタンス属性 `name` を参照するには、空欄に何を書く？
#
# - A. `self.name`
# - B. `name`
# - C. `this.name`
# - D. `Dog.name`

# %%
class Dog:
    def __init__(self, name):
        self.name = name
    def bark(self):
        return ___ + ' がワン'

print(Dog('ポチ').bark())

# %% [markdown]
# ### 問110 メソッドの定義
# クラス内でメソッドを定義するときに使うキーワードはどれ？（関数と同じ）
#
# - A. `method`
# - B. `func`
# - C. `def`
# - D. `lambda`

# %%
class Counter:
    def __init__(self):
        self.n = 0
    ___ increment(self):
        self.n += 1

# %% [markdown]
# ### 問111 クラス属性
# すべてのインスタンスで共有される「クラス属性」は、クラス本体のどこに書く？（空欄には値 `4` を代入する属性名 legs を書きます）
#
# - A. `self.legs = 4`
# - B. `legs = 4`
# - C. `__init__ legs = 4`
# - D. `class.legs = 4`

# %%
class Dog:
    ___
    def __init__(self, name):
        self.name = name

print(Dog.legs)

# %% [markdown]
# ### 問112 クラスの継承
# `Animal` を継承して `Dog` を定義するには、空欄に何を書く？
#
# - A. `class Dog(Animal):`
# - B. `class Dog extends Animal:`
# - C. `class Dog : Animal`
# - D. `class Dog inherits Animal:`

# %%
class Animal:
    pass

___
    pass

# %% [markdown]
# ### 問113 親クラスのメソッド呼び出し（super）
# 子クラスの `__init__` から親クラスの `__init__` を呼ぶには、空欄に入る組み込み関数はどれ？
#
# - A. `parent`
# - B. `base`
# - C. `super`
# - D. `self`

# %%
class Animal:
    def __init__(self, name):
        self.name = name

class Dog(Animal):
    def __init__(self, name, breed):
        ___().__init__(name)
        self.breed = breed

# %% [markdown]
# ### 問114 メソッドのオーバーライド
# 子クラスで親と同名のメソッドを定義して動作を上書きすることを何と呼ぶ？（空欄には親と同名メソッド定義を入れる。適切なのは？）
#
# - A. `def speak(self):`
# - B. `override speak(self):`
# - C. `def speak(cls):`
# - D. `def super_speak(self):`

# %%
class Animal:
    def speak(self):
        return '...'

class Dog(Animal):
    ___
        return 'ワン'

# %% [markdown]
# ### 問115 __str__ による文字列表現
# `print(obj)` や `str(obj)` のときに呼ばれる、見やすい文字列表現を返す特殊メソッドはどれ？
#
# - A. `__repr__`
# - B. `__str__`
# - C. `__name__`
# - D. `__format__`

# %%
class Dog:
    def __init__(self, name):
        self.name = name
    def ___(self):
        return f'Dog({self.name})'

print(Dog('ポチ'))

# %% [markdown]
# ### 問116 インスタンスの生成
# クラスからインスタンス（オブジェクト）を作るには、どのように書く？（空欄にはクラス名を使った生成式を入れる）
#
# - A. `new Dog()`
# - B. `Dog.new()`
# - C. `Dog()`
# - D. `create Dog()`

# %%
class Dog:
    pass

d = ___
print(type(d))

# %% [markdown]
# ### 問117 インスタンスの型判定
# あるオブジェクトが指定クラス（またはそのサブクラス）のインスタンスか判定する組み込み関数はどれ？
#
# - A. `type`
# - B. `isinstance`
# - C. `issubclass`
# - D. `hasattr`

# %%
class Dog:
    pass

d = Dog()
print(___(d, Dog))

# %% [markdown]
# ### 問118 クラスメソッド
# 第1引数にクラス自身（`cls`）を受け取るメソッドを定義するデコレータはどれ？
#
# - A. `@staticmethod`
# - B. `@property`
# - C. `@classmethod`
# - D. `@abstractmethod`

# %%
class Dog:
    count = 0
    ___
    def create(cls):
        cls.count += 1
        return cls()

# %% [markdown]
# ### 問119 静的メソッド
# `self` も `cls` も受け取らない、クラスに属する通常の関数を定義するデコレータはどれ？
#
# - A. `@classmethod`
# - B. `@staticmethod`
# - C. `@property`
# - D. `@method`

# %%
class MathUtil:
    ___
    def add(a, b):
        return a + b

print(MathUtil.add(2, 3))

# %% [markdown]
# ### 問120 プロパティ
# メソッドを属性のようにアクセスできるようにするデコレータはどれ？
#
# - A. `@property`
# - B. `@getter`
# - C. `@attribute`
# - D. `@classmethod`

# %%
class Circle:
    def __init__(self, r):
        self.r = r
    ___
    def area(self):
        return 3.14 * self.r ** 2

print(Circle(2).area)
