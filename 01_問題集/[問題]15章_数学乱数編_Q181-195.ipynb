# %% [markdown]
# # 【問題集】第15章：数学・乱数編（math / random）
#
# Python 3 エンジニア認定基礎試験 対策 / 問181〜問195（解答・解説なし・生徒配布用）
#
# 各問の選択肢から正解を選び、コードセルの `___`（アンダーバー3つ）を埋めて実行してみましょう。

# %% [markdown]
# ### 問181. math.sqrt() で平方根を求める
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.sqrt(25))
# ```
#
# **【選択肢】**
# - A) 5
# - B) 5.0
# - C) 12.5
# - D) 625

# %%
# math モジュールをインポートし、平方根を求める関数を埋めてください。
import math
print(math.___(25))   # 5.0

# %% [markdown]
# ### 問182. math.floor() で切り捨て
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.floor(3.9))
# print(math.floor(-3.1))
# ```
#
# **【選択肢】**
# - A) 3 / -3
# - B) 3 / -4
# - C) 4 / -3
# - D) 4 / -4

# %%
# 小数点以下を切り捨てて、その数以下の最大の整数を返す関数を埋めてください。
import math
print(math.___(3.9))    # 3
print(math.___(-3.1))   # -4

# %% [markdown]
# ### 問183. math.ceil() で切り上げ
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.ceil(3.1))
# print(math.ceil(-3.9))
# ```
#
# **【選択肢】**
# - A) 4 / -3
# - B) 3 / -4
# - C) 4 / -4
# - D) 3 / -3

# %%
# その数以上の最小の整数を返す関数を埋めてください。
import math
print(math.___(3.1))    # 4
print(math.___(-3.9))   # -3

# %% [markdown]
# ### 問184. math.pow() とべき乗演算子の違い
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.pow(2, 3))
# print(2 ** 3)
# ```
#
# **【選択肢】**
# - A) 8 / 8（両方int）
# - B) 8.0 / 8（float / int）
# - C) 8.0 / 8.0（両方float）
# - D) エラーになる

# %%
# math.pow は常に float を返します。累乗を求める関数名を埋めてください。
import math
print(math.___(2, 3))   # 8.0
print(2 ** 3)             # 8

# %% [markdown]
# ### 問185. math.trunc() で小数部を切り捨てる
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.trunc(3.9))
# print(math.trunc(-3.9))
# ```
#
# **【選択肢】**
# - A) 3 / -4
# - B) 4 / -3
# - C) 3 / -3
# - D) 4 / -4

# %%
# 符号に関係なく、小数部分を単純に切り捨てる(0方向に丸める)関数を埋めてください。
import math
print(math.___(3.9))    # 3
print(math.___(-3.9))   # -3

# %% [markdown]
# ### 問186. math.fabs() と組み込み abs() の違い
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.fabs(-5))
# print(abs(-5))
# ```
#
# **【選択肢】**
# - A) 5.0 / 5（float / int）
# - B) 5 / 5（両方int）
# - C) 5.0 / 5.0（両方float）
# - D) エラーになる

# %%
# 絶対値を返す math モジュールの関数を埋めてください（常に float を返します）。
import math
print(math.___(-5))   # 5.0
print(abs(-5))          # 5

# %% [markdown]
# ### 問187. math.gcd() で最大公約数を求める
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.gcd(12, 18))
# ```
#
# **【選択肢】**
# - A) 2
# - B) 3
# - C) 6
# - D) 36

# %%
# 2つの整数の最大公約数(greatest common divisor)を求める関数を埋めてください。
import math
print(math.___(12, 18))   # 6

# %% [markdown]
# ### 問188. math.hypot() で斜辺の長さを求める
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.hypot(3, 4))
# ```
#
# **【選択肢】**
# - A) 7.0
# - B) 5.0
# - C) 12.0
# - D) 25.0

# %%
# 直角三角形の斜辺の長さ（ユークリッド距離）を求める関数を埋めてください。
import math
print(math.___(3, 4))   # 5.0

# %% [markdown]
# ### 問189. math.log() で対数を求める
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# import math
# print(math.log(8, 2))
# ```
#
# **【選択肢】**
# - A) 3.0
# - B) 4.0
# - C) 8.0
# - D) 2.0

# %%
# 第2引数を底とする対数を求める関数を埋めてください。
import math
print(math.___(8, 2))   # 3.0

# %% [markdown]
# ### 問190. random.random() で乱数を生成する
#
# 次のコードについて、`random.random()` が返す値の範囲として正しいものを選択肢から選んでください。
#
# ```python
# import random
# x = random.random()
# print(x)
# ```
#
# **【選択肢】**
# - A) 0以上1未満のfloat
# - B) 1以上100以下のint
# - C) -1以上1以下のfloat
# - D) 常に0.5

# %%
# 0.0 以上 1.0 未満の乱数(float)を返す関数を埋めてください。
import random
x = random.___()
print(0 <= x < 1)   # True

# %% [markdown]
# ### 問191. random.randint() で範囲を指定した整数の乱数
#
# 次のコードについて、n が取りうる値の範囲として正しいものを選択肢から選んでください。
#
# ```python
# import random
# n = random.randint(1, 6)
# print(n)
# ```
#
# **【選択肢】**
# - A) 1以上6未満の整数
# - B) 1以上6以下の整数
# - C) 0以上6以下の整数
# - D) 0.0以上6.0未満の小数

# %%
# 1以上6以下（両端を含む）の整数の乱数を1回だけ生成する関数を埋めてください。
import random
n = random.___(1, 6)
print(1 <= n <= 6)   # True

# %% [markdown]
# ### 問192. random.uniform() で範囲を指定した小数の乱数
#
# 次のコードについて、x が取りうる値の範囲として正しいものを選択肢から選んでください。
#
# ```python
# import random
# x = random.uniform(1.0, 10.0)
# print(x)
# ```
#
# **【選択肢】**
# - A) 1以上10以下の整数
# - B) 1.0以上10.0以下のfloat
# - C) 0.0以上1.0未満のfloat
# - D) 1.0以上10.0未満のint

# %%
# 1.0以上10.0以下の範囲でfloatの乱数を返す関数を埋めてください。
import random
x = random.___(1.0, 10.0)
print(1.0 <= x <= 10.0)   # True

# %% [markdown]
# ### 問193. random.choice() でリストから1つ選ぶ
#
# 次のコードについて、出力として正しいものを選択肢から選んでください。
#
# ```python
# import random
# fruits = ["apple", "banana", "cherry"]
# print(random.choice(fruits))
# ```
#
# **【選択肢】**
# - A) リストの中からランダムに選ばれた1つの要素
# - B) リストを丸ごとシャッフルしたもの
# - C) 先頭の要素固定
# - D) 3つの要素をカンマ区切りで結合した文字列

# %%
# シーケンス(リストなど)からランダムに1つの要素を選ぶ関数を埋めてください。
import random
fruits = ["apple", "banana", "cherry"]
print(random.___(fruits) in fruits)   # True

# %% [markdown]
# ### 問194. random.shuffle() でリストをシャッフルする
#
# 次のコードについて、正しい説明を選択肢から選んでください。
#
# ```python
# import random
# nums = [1, 2, 3, 4, 5]
# random.shuffle(nums)
# print(nums)
# ```
#
# **【選択肢】**
# - A) nums の要素の並び順がその場で(in-place)シャッフルされる
# - B) シャッフルされた新しいリストが返り値として返る（numsは変化しない）
# - C) 要素がソートされる
# - D) エラーになる

# %%
# リストの要素の並び順をその場でシャッフルする関数を埋めてください（戻り値は None）。
import random
nums = [1, 2, 3, 4, 5]
result = random.___(nums)
print(result)         # None
print(sorted(nums))   # [1, 2, 3, 4, 5]

# %% [markdown]
# ### 問195. random.sample() で重複なくランダムに複数選ぶ
#
# 次のコードについて、正しい説明を選択肢から選んでください。
#
# ```python
# import random
# nums = [1, 2, 3, 4, 5]
# result = random.sample(nums, 3)
# print(len(result))
# print(len(set(result)))
# ```
#
# **【選択肢】**
# - A) 3 / 3（重複なしで3個選ばれる）
# - B) 3 / 1（同じ要素が選ばれることがある）
# - C) 5 / 5（全要素が返る）
# - D) エラーになる

# %%
# 母集団から重複なくk個の要素をランダムに選ぶ関数を埋めてください。
import random
nums = [1, 2, 3, 4, 5]
result = random.___(nums, 3)
print(len(result))        # 3
print(len(set(result)))   # 3(重複なし)
