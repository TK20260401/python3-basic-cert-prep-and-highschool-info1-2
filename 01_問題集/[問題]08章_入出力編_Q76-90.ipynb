# %% [markdown]
# # 第8章 入出力編（Q76-90）問題集
#
# Python 3 エンジニア認定基礎試験 オリジナル問題集。各コードセルの `___`（3つのアンダースコア）に入る選択肢（A〜D）を選んでください。

# %% [markdown]
# ### 問76 str.format() の基本
# 次のコードで `'Alice さん (30 歳)'` と表示するには、空欄に入る文字列メソッドはどれ？
#
# - A. `format`
# - B. `replace`
# - C. `join`
# - D. `split`

# %%
name = 'Alice'
age = 30
print('{} さん ({} 歳)'.___(name, age))

# %% [markdown]
# ### 問77 f-string（フォーマット済み文字列リテラル）
# f-string で変数を埋め込むには、文字列リテラルの前にどの接頭辞を付ける？
#
# - A. `b`
# - B. `r`
# - C. `f`
# - D. `u`

# %%
name = 'Bob'
score = 95
print(___'{name} の得点は {score} 点')

# %% [markdown]
# ### 問78 f-string の書式指定（小数点以下2桁）
# 円周率を小数点以下2桁で `3.14` と表示するには、空欄に入る書式指定はどれ？
#
# - A. `:2f`
# - B. `:.2f`
# - C. `:2d`
# - D. `:.2e`

# %%
import math
print(f'{math.pi___}')

# %% [markdown]
# ### 問79 str.format() での桁揃え（右寄せ）
# 数値を幅5で右寄せして `'   42'` と表示するには、空欄に入る書式指定はどれ？
#
# - A. `{:<5}`
# - B. `{:^5}`
# - C. `{:>5}`
# - D. `{:=5}`

# %%
print('{___}'.format(42))

# %% [markdown]
# ### 問80 print() の sep 引数
# `print('2026', '04', '01')` の区切りを `-` にして `2026-04-01` と表示するには、空欄の引数はどれ？
#
# - A. `end='-'`
# - B. `sep='-'`
# - C. `split='-'`
# - D. `join='-'`

# %%
print('2026', '04', '01', ___)

# %% [markdown]
# ### 問81 print() の end 引数
# 2つの print を続けても改行せず `AB` と1行で表示するには、1つ目の print の空欄に入る引数はどれ？
#
# - A. `sep=''`
# - B. `end=''`
# - C. `flush=True`
# - D. `file=None`

# %%
print('A', ___)
print('B')

# %% [markdown]
# ### 問82 input() の戻り値
# `input()` で受け取った値を整数として計算に使うには、空欄に入る関数はどれ？（input は常に文字列を返す）
#
# - A. `str`
# - B. `float`
# - C. `int`
# - D. `list`

# %%
s = input('数を入力: ')
n = ___(s)
print(n + 1)

# %% [markdown]
# ### 問83 open() のモード（読み込み）
# ファイルをテキスト読み込み用に開くとき、`open()` の第2引数に指定するモード文字はどれ？
#
# - A. `'w'`
# - B. `'r'`
# - C. `'a'`
# - D. `'x'`

# %%
f = open('data.txt', ___)
text = f.read()
f.close()

# %% [markdown]
# ### 問84 with 文でのファイル書き込み
# ファイルへ文字列を書き込むメソッドはどれ？（with で自動的に close される）
#
# - A. `read`
# - B. `append`
# - C. `write`
# - D. `print`

# %%
with open('out.txt', 'w') as f:
    f.___('Hello\n')

# %% [markdown]
# ### 問85 ファイルの1行ずつ読み込み
# ファイルオブジェクトを for 文で回すと、各要素は何になる？（空欄はファイルオブジェクト自身）
#
# - A. 1文字ずつ
# - B. 1行ずつ
# - C. 1単語ずつ
# - D. バイト列

# %%
with open('data.txt') as f:
    for line in ___:
        print(line.rstrip())

# %% [markdown]
# ### 問86 文字列の前後空白除去
# `'  hello  '` の前後の空白を取り除いて `'hello'` にする文字列メソッドはどれ？
#
# - A. `strip`
# - B. `split`
# - C. `replace`
# - D. `find`

# %%
s = '  hello  '
print(s.___())

# %% [markdown]
# ### 問87 文字列の分割
# `'a,b,c'` をカンマで区切って `['a', 'b', 'c']` にする文字列メソッドはどれ？
#
# - A. `join`
# - B. `split`
# - C. `slice`
# - D. `partition`

# %%
s = 'a,b,c'
print(s.___(','))

# %% [markdown]
# ### 問88 リストの連結（join）
# `['a', 'b', 'c']` を `-` でつないで `'a-b-c'` にするには、空欄に入る文字列メソッドはどれ？
#
# - A. `split`
# - B. `format`
# - C. `join`
# - D. `append`

# %%
parts = ['a', 'b', 'c']
print('-'.___(parts))

# %% [markdown]
# ### 問89 文字列の置換
# `'2026/04/01'` の `/` を `-` に置き換えて `'2026-04-01'` にする文字列メソッドはどれ？
#
# - A. `replace`
# - B. `strip`
# - C. `translate`
# - D. `swapcase`

# %%
s = '2026/04/01'
print(s.___('/', '-'))

# %% [markdown]
# ### 問90 f-string での repr 変換（!r）
# f-string で値を `repr()` 形式（引用符付き）で埋め込むには、空欄に入る変換指定はどれ？
#
# - A. `!s`
# - B. `!r`
# - C. `!a`
# - D. `:r`

# %%
name = 'Bob'
print(f'{name___}')
