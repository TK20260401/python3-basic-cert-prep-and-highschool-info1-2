# %% [markdown]
# # 【問題集】第5章：データ構造（リスト詳細 / タプル / 集合 / 辞書）
#
# Python 3 エンジニア認定基礎試験 対策 / 問31〜問45（解答・解説なし・生徒配布用）
#
# 各問の選択肢から正解を選び、コードセルの `___`（アンダーバー3つ）を埋めて実行してみましょう。

# %% [markdown]
# ### 問31. リストへの要素追加（append）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# nums = [1, 2, 3]
# nums.append(4)
# print(nums)
# ```
#
# **【選択肢】**
# - A) [1, 2, 3]
# - B) [1, 2, 3, 4]
# - C) [4, 1, 2, 3]
# - D) [1, 2, 3, [4]]

# %%
# リストの末尾に 4 を追加するメソッドを埋めてください。
nums = [1, 2, 3]
nums.___(4)
print(nums)   # [1, 2, 3, 4]

# %% [markdown]
# ### 問32. リストのスライス
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# letters = ['a', 'b', 'c', 'd', 'e']
# print(letters[1:4])
# ```
#
# **【選択肢】**
# - A) ['a', 'b', 'c']
# - B) ['b', 'c', 'd']
# - C) ['b', 'c', 'd', 'e']
# - D) ['a', 'b', 'c', 'd']

# %%
# インデックス1から3まで（4は含まない）を取り出すスライスを埋めてください。
letters = ['a', 'b', 'c', 'd', 'e']
print(letters[___])   # ['b', 'c', 'd']

# %% [markdown]
# ### 問33. 負のインデックス
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# data = [10, 20, 30, 40]
# print(data[-1], data[-2])
# ```
#
# **【選択肢】**
# - A) 10 20
# - B) 40 30
# - C) 30 40
# - D) エラーになる

# %%
# 末尾の要素とその1つ前の要素を、負のインデックスで取り出してください。
data = [10, 20, 30, 40]
print(data[___], data[___])   # 40 30

# %% [markdown]
# ### 問34. リスト内包表記
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# squares = [x**2 for x in range(5)]
# print(squares)
# ```
#
# **【選択肢】**
# - A) [0, 1, 2, 3, 4]
# - B) [1, 4, 9, 16, 25]
# - C) [0, 1, 4, 9, 16]
# - D) [0, 2, 4, 6, 8]

# %%
# 0〜4 の各値を2乗したリストを内包表記で作ります。式の部分を埋めてください。
squares = [___ for x in range(5)]
print(squares)   # [0, 1, 4, 9, 16]

# %% [markdown]
# ### 問35. sorted() による並べ替え
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# nums = [3, 1, 2]
# result = sorted(nums)
# print(result, nums)
# ```
#
# **【選択肢】**
# - A) [1, 2, 3] [1, 2, 3]
# - B) [1, 2, 3] [3, 1, 2]
# - C) [3, 2, 1] [3, 1, 2]
# - D) [3, 1, 2] [1, 2, 3]

# %%
# 元のリストを変更せず、昇順に並べ替えた新しいリストを返す関数を埋めてください。
nums = [3, 1, 2]
result = ___(nums)
print(result, nums)   # [1, 2, 3] [3, 1, 2]

# %% [markdown]
# ### 問36. タプルの生成と不変性
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# point = (10, 20)
# print(point[0])
# ```
#
# **【選択肢】**
# - A) 10
# - B) 20
# - C) (10, 20)
# - D) エラーになる

# %%
# タプル point の最初の要素（10）を取り出してください。
point = (10, 20)
print(point[___])   # 10

# %% [markdown]
# ### 問37. タプルのアンパック代入
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# a, b = (1, 2)
# print(a + b)
# ```
#
# **【選択肢】**
# - A) 1
# - B) 2
# - C) 3
# - D) (1, 2)

# %%
# タプルの2要素を2つの変数 a, b に同時に代入（アンパック）してください。
___ = (1, 2)
print(a + b)   # 3

# %% [markdown]
# ### 問38. 集合（set）による重複の除去
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# nums = [1, 2, 2, 3, 3, 3]
# unique = set(nums)
# print(len(unique))
# ```
#
# **【選択肢】**
# - A) 6
# - B) 3
# - C) 2
# - D) 1

# %%
# リストから重複を取り除くために、集合を作る組み込み関数を埋めてください。
nums = [1, 2, 2, 3, 3, 3]
unique = ___(nums)
print(len(unique))   # 3

# %% [markdown]
# ### 問39. 集合の積（共通部分）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# a = {1, 2, 3}
# b = {2, 3, 4}
# print(a & b)
# ```
#
# **【選択肢】**
# - A) {1, 2, 3, 4}
# - B) {2, 3}
# - C) {1, 4}
# - D) {1}

# %%
# 2つの集合 a と b の共通部分（積集合）を求める演算子を埋めてください。
a = {1, 2, 3}
b = {2, 3, 4}
print(a ___ b)   # {2, 3}

# %% [markdown]
# ### 問40. 辞書（dict）の値の取得
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# scores = {"math": 80, "eng": 90}
# print(scores["eng"])
# ```
#
# **【選択肢】**
# - A) 80
# - B) 90
# - C) eng
# - D) エラーになる

# %%
# キー "eng" に対応する値を取り出してください。
scores = {"math": 80, "eng": 90}
print(scores[___])   # 90

# %% [markdown]
# ### 問41. 辞書へのキーと値の追加
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# d = {"a": 1}
# d["b"] = 2
# print(d)
# ```
#
# **【選択肢】**
# - A) {"a": 1}
# - B) {"a": 1, "b": 2}
# - C) {"b": 2}
# - D) {"a": 1, 2}

# %%
# 辞書 d に、キー "b"・値 2 を追加してください。
d = {"a": 1}
d[___] = 2
print(d)   # {'a': 1, 'b': 2}

# %% [markdown]
# ### 問42. 辞書の get() メソッド
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# d = {"x": 1}
# print(d.get("y", 0))
# ```
#
# **【選択肢】**
# - A) 1
# - B) 0
# - C) None
# - D) KeyError

# %%
# キー "y" が無いとき、既定値 0 を返すメソッドを埋めてください。
d = {"x": 1}
print(d.___("y", 0))   # 0

# %% [markdown]
# ### 問43. 辞書を items() でループ
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# d = {"a": 1, "b": 2}
# for k, v in d.items():
#     print(k, v)
# ```
#
# **【選択肢】**
# - A) a b（キーのみ）
# - B) 1 2（値のみ）
# - C) a 1 と b 2（キーと値の組）
# - D) エラーになる

# %%
# 辞書からキーと値の組を同時に取り出すメソッドを埋めてください。
d = {"a": 1, "b": 2}
for k, v in d.___():
    print(k, v)   # a 1 / b 2

# %% [markdown]
# ### 問44. in 演算子によるキーの存在確認
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# d = {"apple": 100, "banana": 200}
# print("apple" in d)
# ```
#
# **【選択肢】**
# - A) True
# - B) False
# - C) 100
# - D) エラーになる

# %%
# 辞書 d にキー "apple" が存在するかを判定する演算子を埋めてください。
d = {"apple": 100, "banana": 200}
print("apple" ___ d)   # True

# %% [markdown]
# ### 問45. ネストしたデータ構造へのアクセス
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# data = {"users": [{"name": "Aoi"}, {"name": "Ben"}]}
# print(data["users"][1]["name"])
# ```
#
# **【選択肢】**
# - A) Aoi
# - B) Ben
# - C) name
# - D) エラーになる

# %%
# users リストの2番目（インデックス1）の要素の "name" を取り出してください。
data = {"users": [{"name": "Aoi"}, {"name": "Ben"}]}
print(data["users"][___]["name"])   # Ben
