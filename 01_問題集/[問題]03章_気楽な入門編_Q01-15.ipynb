# %% [markdown]
# # 【問題集】第3章：気楽な入門編（数値・文字列・リスト）
#
# Python 3 エンジニア認定基礎試験 対策 / 問1〜問15（解答・解説なし・生徒配布用）
#
# 各問の選択肢から正解を選び、コードセルの `___`（アンダーバー3つ）を埋めて実行してみましょう。

# %% [markdown]
# ### 問1. 整数と浮動小数点数の演算・余り・切り捨て除算
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# print(17 / 3)
# print(17 // 3)
# print(17 % 3)
# ```
#
# **【選択肢】**
# - A) 5.666666666666667 / 5 / 2
# - B) 5 / 5 / 2
# - C) 5.666666666666667 / 5.0 / 2.0
# - D) 6 / 5 / 2

# %%
# ① 通常の割り算、② 切り捨て除算、③ 余り を出力してください。
print(17 ___ 3)
print(17 ___ 3)
print(17 ___ 3)

# %% [markdown]
# ### 問2. べき乗の計算
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# print(2 ** 10)
# print(5 ** 2)
# ```
#
# **【選択肢】**
# - A) 20 / 10
# - B) 1024 / 25
# - C) 100 / 10
# - D) 1024 / 10

# %%
# 「2の10乗」と「5の2乗」を出力してください。
print(2 ___ 10)
print(5 ___ 2)

# %% [markdown]
# ### 問3. エスケープシーケンスとraw文字列
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# print("C:\name\test")
# print(r"C:\name\test")
# ```
#
# **【選択肢】**
# - A) 1行目・2行目とも `C:\name\test`
# - B) 1行目は改行やタブが解釈され、2行目は `C:\name\test`
# - C) 1行目・2行目とも改行やタブが解釈される
# - D) エラーになる

# %%
# バックスラッシュをそのまま表示する raw文字列にしてください。
print(___"C:\name\test")

# %% [markdown]
# ### 問4. 複数行文字列と行末の \
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# print("""\
# Usage: thingy [OPTIONS]
#      -h    Display this help""")
# ```
#
# **【選択肢】**
# - A) 先頭に空行が入って表示される
# - B) 先頭に空行が入らず、`Usage:` の行から表示される
# - C) すべて1行につながって表示される
# - D) エラーになる

# %%
# トリプルクォート開始直後の「先頭の空行」を抑制する1文字を入れて実行してください。
print("""___
Usage: thingy [OPTIONS]
     -h    Display this help""")

# %% [markdown]
# ### 問5. 文字列のインデックス（正・負）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# word = "Python"
# print(word[0])
# print(word[-1])
# ```
#
# **【選択肢】**
# - A) P / n
# - B) P / o
# - C) y / n
# - D) P / P

# %%
# 先頭の文字と末尾の文字を出力してください。
word = "Python"
print(word[___])   # 先頭 "P"
print(word[___])   # 末尾 "n"

# %% [markdown]
# ### 問6. 文字列のスライス（基本・省略）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# word = "Python"
# print(word[:3])
# print(word[2:])
# ```
#
# **【選択肢】**
# - A) Pyt / thon
# - B) Pyt / ython
# - C) Pytho / thon
# - D) Pyth / hon

# %%
# ① 先頭から3文字 "Pyt"、② インデックス2以降 "thon" を出力してください。
word = "Python"
print(word[___])   # "Pyt"
print(word[___])   # "thon"

# %% [markdown]
# ### 問7. スライス応用（範囲外・ステップ値）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# word = "Python"
# print(word[4:100])
# print(word[::2])
# ```
#
# **【選択肢】**
# - A) エラー / Pto
# - B) on / Pto
# - C) on / yhn
# - D) エラー / Python

# %%
# ① 範囲外でも安全に末尾まで取り出す（"on"）、② 1文字おきに取り出す（"Pto"）
word = "Python"
print(word[4:___])   # "on"
print(word[___])     # "Pto"

# %% [markdown]
# ### 問8. 文字列の不変性（イミュータブル）
#
# 次のコードを実行したときの結果として正しいものを選択肢から選んでください。
#
# ```python
# word = "Python"
# word[0] = "J"
# print(word)
# ```
#
# **【選択肢】**
# - A) Jython と表示される
# - B) Python と表示される
# - C) TypeError が発生する
# - D) J と表示される

# %%
# 文字列はイミュータブル。新しい文字列を作り "Jython" を出力してください。
word = "Python"
new_word = "J" + word[___]
print(new_word)   # "Jython"

# %% [markdown]
# ### 問9. 組み込み関数 len()
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# s = "supercalifragilistic"
# nums = [10, 20, 30, 40]
# print(len(s))
# print(len(nums))
# ```
#
# **【選択肢】**
# - A) 20 / 4
# - B) 19 / 4
# - C) 20 / 3
# - D) 21 / 4

# %%
# 文字列の長さとリストの要素数を出力してください。
s = "supercalifragilistic"
nums = [10, 20, 30, 40]
print(___(s))
print(___(nums))

# %% [markdown]
# ### 問10. リストのインデックスとスライス
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# squares = [1, 4, 9, 16, 25]
# print(squares[0])
# print(squares[-1])
# print(squares[2:])
# ```
#
# **【選択肢】**
# - A) 1 / 25 / [9, 16, 25]
# - B) 1 / 16 / [9, 16, 25]
# - C) 0 / 25 / [16, 25]
# - D) 1 / 25 / [16, 25]

# %%
# ① 先頭要素 1、② 末尾要素 25、③ インデックス2以降 [9, 16, 25] を出力してください。
squares = [1, 4, 9, 16, 25]
print(squares[___])   # 1
print(squares[___])   # 25
print(squares[___])   # [9, 16, 25]

# %% [markdown]
# ### 問11. リストの要素書き換え（ミュータブル）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# cubes = [1, 8, 27, 65, 125]
# cubes[3] = 64
# print(cubes)
# ```
#
# **【選択肢】**
# - A) [1, 8, 27, 65, 125]
# - B) [1, 8, 27, 64, 125]
# - C) TypeError が発生する
# - D) [1, 8, 27, 64]

# %%
# リストはミュータブル。間違っている 65 を正しい 64 に修正してください。
cubes = [1, 8, 27, 65, 125]
cubes[___] = 64
print(cubes)   # [1, 8, 27, 64, 125]

# %% [markdown]
# ### 問12. スライスによる一括代入と要素削除
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# letters = ['a', 'b', 'c', 'd', 'e', 'f']
# letters[2:5] = ['C', 'D', 'E']
# print(letters)
# letters[2:5] = []
# print(letters)
# ```
#
# **【選択肢】**
# - A) ['a','b','C','D','E','f'] / ['a','b','f']
# - B) ['a','b','C','D','E','f'] / ['a','b']
# - C) ['a','b','c','d','e','f'] / ['a','b','f']
# - D) ['a','b','C','D','E'] / ['a','b']

# %%
# ① 2〜4を ['C','D','E'] に置換、② 同じ範囲を空リストで削除
letters = ['a', 'b', 'c', 'd', 'e', 'f']
letters[___] = ['C', 'D', 'E']
print(letters)   # ['a', 'b', 'C', 'D', 'E', 'f']
letters[2:5] = ___
print(letters)   # ['a', 'b', 'f']

# %% [markdown]
# ### 問13. リストへの要素追加（append）
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# squares = [1, 4, 9]
# squares.append(16)
# squares.append(5 ** 2)
# print(squares)
# ```
#
# **【選択肢】**
# - A) [1, 4, 9, 16, 5]
# - B) [1, 4, 9, 16, 25]
# - C) [1, 4, 9, 21]
# - D) [1, 4, 9, 16, 10]

# %%
# リストの末尾に 16 と 5の2乗(25) を追加してください。
squares = [1, 4, 9]
squares.___(16)
squares.___(5 ** 2)
print(squares)   # [1, 4, 9, 16, 25]

# %% [markdown]
# ### 問14. ネストされたリストへのアクセス
#
# 次のコードを実行したときの出力結果として正しいものを選択肢から選んでください。
#
# ```python
# a = ['a', 'b', 'c']
# n = [1, 2, 3]
# x = [a, n]
# print(x[0])
# print(x[0][1])
# ```
#
# **【選択肢】**
# - A) ['a', 'b', 'c'] / b
# - B) a / b
# - C) ['a', 'b', 'c'] / a
# - D) [1, 2, 3] / 2

# %%
# ① 1つ目のリスト全体、② その中の 'b' を出力してください。
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
print(x[___])        # ['a', 'b', 'c']
print(x[___][___])   # 'b'

# %% [markdown]
# ### 問15. 変数の代入と対話モードの _
#
# 対話モードで次を順に実行しました。出力結果として正しいものを選択肢から選んでください。
#
# ```python
# tax = 12.5 / 100
# price = 100.50
# price * tax
# round(_, 2)
# ```
#
# **【選択肢】**
# - A) 12.5625 → 12.56
# - B) 12.5625 → 12.5625
# - C) エラー → エラー
# - D) 12.56 → 12.56

# %%
# Colabのコードセルでは行の値が自動表示されないため print で確認します。
tax = 12.5 / 100
price = 100.50
result = price * tax
print(result)              # 12.5625
print(round(___, 2))       # 12.56（直前の値 result を丸める）
